# %% [markdown]
# ## Gucci Scraper

# %%
# import statements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager
import urllib.request
from urllib.request import Request, urlopen
import requests
#used to extract data from html files
from bs4 import BeautifulSoup
from requests import get
import csv

# %%
#CREATE A LIST TO PUT IN EXTRACTED PRODUCT DETAILS

# start with an empty list - add headers
rows = []
rows.append(['prname','page2','price','authnumber','sizeInch',
             'color_material','accessories','outside_condition',
             'inside_condition','other','smell','product_nr'])

#there are 7 pages for gucci
for i in range(1,8):

    # specify the url 
    pagenr = str(i)
    urlpage =  'https://amorevintagejapan.com/collections/gucci/bags?page='+pagenr
    print(urlpage)
    #print(urlpage)
    req = urllib.request.Request(urlpage)
    # providing a basic user-agent so our scraper doesn't get blocked
    # query the website and return the html to the variable 'page'
    req.add_header('User-Agent', 'Mozilla/5.0')
    page = urllib.request.urlopen(req)
    soup = BeautifulSoup(page, 'html.parser')
    
    #here we are only getting the sold out products from a page

    #in the soup find all product cards
    results = soup.find_all('div',attrs={'class': 'grid__item grid-product small--one-half medium-up--one-quarter'})
    #check if the results we got corresponds to the number of elements on a page
    #print('Number of results', len(results))
    #printing the first row of results
    #print(results[1])
    
    #GET THE INFO FROM EACH ITEM IN THE PAGE
    for i in range(len(results)):
        #go per item/line of results
        data = results[i]

        #extract seperate elements
        page2 = data.find('a').get('href')
        prname = data.find('div',attrs={'class': 'grid-product__title grid-product__title--body'}).getText()
        price = data.find('span',attrs={'class': 'money'}).getText()
        price = price.strip('¥').strip('JPY ').replace('','')

        # go the the product's own page
        url2 = 'https://amorevintagejapan.com/'+page2
        req2 = urllib.request.Request(url2)
        req2.add_header('User-Agent', 'Mozilla/5.0')
        getpage = urllib.request.urlopen(req2)
        soup2 = BeautifulSoup(getpage, 'html.parser')
        #in the soup find the table with product details
        itemdetails = soup2.find_all('table',attrs={'class': 'item_info'})
        lines = soup2.find('table').find_all('td')

        #GETTING SEPERATE ELEMENTS FROM PRODUCT DETAILS TABLE
        authnumber = lines[0].getText()
        sizeinch = lines[2].getText()
        color_material = lines[4].getText()
        accessories = lines[5].getText()
        outside_condition = lines[-4].getText()
        inside_condition = lines[-3].getText()
        other = lines[-2].getText()
        smell = lines[-1].getText()
        product_nr = lines[6].getText()

        #CLEANING UP DATA
        authnumber = authnumber.strip('\n\r').replace('','')
        # sizeinch is a string, manipulate further to clean up?
        # could slice sizeinch in some way to extract strapdrop as a seperate element
        sizeinch = sizeinch.strip('\n\r').replace('','')
        # could slice color_material in some way to extract seperate elements - or later in pandas
        color_material = color_material.strip('\n\r').replace('','')
        accessories = accessories.strip('\n\r').replace('','')
        outside_condition = outside_condition.strip('\n\r').replace('','')
        # may need further cleaning up still contains \r\n\r\n
        inside_condition = inside_condition.strip('\n\r').replace('','')
        other = other.strip('\n\r').replace('','')
        smell = smell.strip('\n\r').replace('','')
        product_nr = product_nr.strip('\n\r').replace('','')

        rows.append([prname, page2, price,authnumber,sizeinch,color_material,
                     accessories,outside_condition,inside_condition,other,smell,product_nr])

print(rows)
# Out:
# https://amorevintagejapan.com/collections/gucci/bags?page=1
# https://amorevintagejapan.com/collections/gucci/bags?page=2
# https://amorevintagejapan.com/collections/gucci/bags?page=3
# https://amorevintagejapan.com/collections/gucci/bags?page=4
# https://amorevintagejapan.com/collections/gucci/bags?page=5
# https://amorevintagejapan.com/collections/gucci/bags?page=6
# https://amorevintagejapan.com/collections/gucci/bags?page=7
# [['prname', 'page2', 'price', 'authnumber', 'sizeInch', 'color_material', 'accessories', 'outside_condition', 'inside_condition', 'other', 'smell', 'product_nr'], ['GUCCI GG Pattern Hand Bag Brown Beige', '/collections/gucci/products/ao25770', '29,800', ' 34080 002122', ' W 5.9 x H 5.5 x D 3.1 "  Handle Drop. 2.3 "', ' Brown, Beige / Canvas, Leather', ' -', ' Stain, Frayed.There is sign of use overall.', ' There is sign of use overall.', ' -', ' -', ' AO25770'], ['GUCCI GG Shelly Line Mini Clutch Hand Bag Pouch Navy', '/collections/gucci/products/ao25772', '29,800', '38', 'W 7.5 x H 2.0 D 2.9"', 'Navy ,Red,Ivory\r\n/\r\nPVC, Leather', '-', 'Good condition', 'Good condition', '-', '-', 'AO25772'], ['GUCCI Bamboo Line 2way Hand Bag Brown Crocodile', '/collections/gucci/products/ao25290', '298,000', '000 46 0188 426', 'W 8.7 x H 5.9 x D 3.5 "\r\n\r\nHandle Drop. 4.7 "\r\n\r\nStrap Drop. 21.3 "', 'Brown\r\n/\r\nCrocodile Leather, Leather', 'Shoulder Strap, Manual', 'Good condition', 'Good condition', '-', '-', 'AO25290'], ['GUCCI Lady Lock 2way Hand Bag Brown', '/collections/gucci/products/ao25292', '89,800', '000.926.0211', 'W 7.9 x H 6.7 x D 3.1 "\r\n\r\nHandle Drop. 3.1 "\r\n\r\nStrap Drop. 20.5 "', 'Brown\r\n/\r\nLeather', 'Cover of Key, Keys*2, Shoulder Strap', 'Good condition\r\n\r\nscratches', 'Good condition', 'Pocket has stain', '-', 'AO25292'], ['FENDI Zucca Pattern 2way Hand Bag Box Purse Brown', '/collections/gucci/products/ao25113', '178,000', '-', 'W 6.5 x H 5.7 x D 2.8 "\r\n\r\nHandle Drop. 3.1 "\r\n\r\nStrap Drop. 19.3 "', 'Brown\r\n/\r\nCanvas, Leather', 'Shoulder Strap, Dust Bag', 'There is sign of use overall.\r\n\r\nLeather part: scratches.\r\n\r\nCanvas: frayed', 'Good condition', '-', '-', 'AO25113'], ['GUCCI Logos Jackie Hand Bag Purse Black', '/collections/gucci/products/ao24955', '49,800', '001.3735.001998', 'W 10.4 x H 6.3 x D 1.6 "\r\n\r\nHandle Drop. 7.9 "', 'Black\r\n/\r\nLeather', 'Dust Bag', 'AO24955', 'Good condition\r\n\r\nminor scratches', 'Good condition', '-', 'AO24955'], ['GUCCI Bamboo Line Hand Tote Bag Brown', '/collections/gucci/products/ao24613', '69,800', '000.110.3243', 'W 10.6 x H 8.3 x D 3.5 "\r\n\r\nHandle Drop. 4.7 "', 'Brown\r\n/\r\nLeather', 'Manual', 'AO24613', 'Good condition', 'There is sign of use overall.', '-', 'AO24613'], ['GUCCI GG Pattern Shelly Line Travel Shoulder Bag Brown', '/collections/gucci/products/ao24131', '69,800', '153240 204046', 'W 16.5 x H 10.6 x D 9.8 "\r\n\r\nStrap Drop. 9.4 "', 'Brown, Red, Green\r\n/\r\nCanvas, Leather', 'Manual', 'AO24131', 'Good condition\r\n\r\nNear zipper rail: discoloration', 'Good condition', '-', 'AO24131'], ['GUCCI GG Pattern Double Chain Shoulder Bag Black Satin', '/collections/gucci/products/ao23955', '49,800', '-', 'W 8.7 x H 5.5 x D 1.2 "\r\n\r\nStrap Drop.(Single) 17.7 " /(Double) 9.1 "', 'Black\r\n/\r\nSatin', '-', 'AO23955', 'Good condition\r\n\r\nminor scratches', 'Good condition', '-', 'AO23955'], ['GUCCI GG Pattern Shelly Line Hand Bag Brown', '/collections/gucci/products/ao23824', '39,800', '141809 203419', 'W 8.7 x H 3.9 x D 8.3 "\r\n\r\nHandle Drop. 4.3 "', 'Brown, Red, Green\r\n/\r\nCanvas, Leather', '-', 'AO23824', 'Good condition', 'Good condition\r\n\r\nminor discoloration', '-', 'AO23824'], ['GUCCI Bamboo Line 2way Hand Bag Brown', '/collections/gucci/products/ao23669', '148,000', '000.1014.0188. 0', 'W 8.7 x H 5.9 x D 3.1 "\r\n\r\nHandle Drop. 3.9 "\r\n\r\nStrap Drop. 21.7 "', 'Brown/ Leather', 'Shoulder Strap, Manual', 'Good Condition', 'Good Condition', '-', '-', 'AO23669'], ['GUCCI Shelly Line GG Pattern Horsebit Trunk Hand Bag Brown', '/collections/gucci/products/ao23668', '89,800', '-', 'W 9.4 x H 8.3 x D 2.8 "\r\n\r\nHandle Drop. 1.6 "', 'Brown, Red, Green/ Canvas, Leather', 'Coin Purse, Cover of Key, Key*1', 'There is sign of use overall\r\n\r\nScratches, Fraed\r\n\r\nMetal fittings: Rust', 'There is sign of use overall\r\n\r\nStains\r\n\r\nMetal fittings: Rust', '-', '-', 'AO23668'], ['GUCCI GG Pattern S ...

# %%
## Create csv and write rows to output file
with open('amoregucci1.csv','w', newline='') as f_output:
    csv_output = csv.writer(f_output)
    csv_output.writerows(rows)

# %%
from urllib.request import Request, urlopen
import requests


#CREATE A LIST TO PUT IN EXTRACTED PRODUCT DETAILS

# start with an empty list - add headers
rows = []
rows.append(['prname','page2','price','authnumber','sizeInch',
             'color_material','accessories','outside_condition',
             'inside_condition','other','smell','product_nr'])

#there are 7 pages for gucci
for i in range(1,8):

    # specify the url 
    pagenr = str(i)
    urlpage =  'https://amorevintagejapan.com/collections/gucci/bags?page='+pagenr
    print(urlpage)
    req = urllib.request.Request(urlpage)
    # providing a basic user-agent so our scraper doesn't get blocked
    # query the website and return the html to the variable 'page'
    req.add_header('User-Agent', 'Mozilla/5.0')
    page = urllib.request.urlopen(req)
    soup = BeautifulSoup(page, 'html.parser')
    
    #here we are only getting the sold out products from a page

    #in the soup find all product cards
    results = soup.find_all('div',attrs={'class': 'grid__item grid-product small--one-half medium-up--one-quarter grid-product__has-quick-shop'})
    #check if the results we got corresponds to the number of elements on a page
    #print('Number of results', len(results))
    #printing the first row of results
    #print(results[1])
    
    #GET THE INFO FROM EACH ITEM IN THE PAGE
    for i in range(len(results)):
        #go per item/line of results
        data = results[i]

        #extract seperate elements
        page2 = data.find('a').get('href')
        prname = data.find('div',attrs={'class': 'grid-product__title grid-product__title--body'}).getText()
        price = data.find('span',attrs={'class': 'money'}).getText()
        price = price.strip('¥').strip('JPY ').replace('','')

        # go the the product's own page
        url2 = 'https://amorevintagejapan.com/'+page2
        req2 = urllib.request.Request(url2)
        req2.add_header('User-Agent', 'Mozilla/5.0')
        getpage = urllib.request.urlopen(req2)
        soup2 = BeautifulSoup(getpage, 'html.parser')
        #in the soup find the table with product details
        itemdetails = soup2.find_all('table',attrs={'class': 'item_info'})
        lines = soup2.find('table').find_all('td')

        #GETTING SEPERATE ELEMENTS FROM PRODUCT DETAILS TABLE
        authnumber = lines[0].getText()
        sizeinch = lines[2].getText()
        color_material = lines[4].getText()
        accessories = lines[5].getText()
        outside_condition = lines[-4].getText()
        inside_condition = lines[-3].getText()
        other = lines[-2].getText()
        smell = lines[-1].getText()
        product_nr = lines[6].getText()

        #CLEANING UP DATA
        authnumber = authnumber.strip('\n\r').replace('','')
        # sizeinch is a string, manipulate further to clean up?
        # could slice sizeinch in some way to extract strapdrop as a seperate element
        sizeinch = sizeinch.strip('\n\r').replace('','')
        # could slice color_material in some way to extract seperate elements - or later in pandas
        color_material = color_material.strip('\n\r').replace('','')
        accessories = accessories.strip('\n\r').replace('','')
        outside_condition = outside_condition.strip('\n\r').replace('','')
        # may need further cleaning up still contains \r\n\r\n
        inside_condition = inside_condition.strip('\n\r').replace('','')
        other = other.strip('\n\r').replace('','')
        smell = smell.strip('\n\r').replace('','')
        product_nr = product_nr.strip('\n\r').replace('','')

        rows.append([prname, page2, price,authnumber,sizeinch,color_material,
                     accessories,outside_condition,inside_condition,other,smell,product_nr])

print(rows)
# Out:
# https://amorevintagejapan.com/collections/gucci/bags?page=1
# https://amorevintagejapan.com/collections/gucci/bags?page=2
# https://amorevintagejapan.com/collections/gucci/bags?page=3
# https://amorevintagejapan.com/collections/gucci/bags?page=4
# https://amorevintagejapan.com/collections/gucci/bags?page=5
# https://amorevintagejapan.com/collections/gucci/bags?page=6
# https://amorevintagejapan.com/collections/gucci/bags?page=7
# [['prname', 'page2', 'price', 'authnumber', 'sizeInch', 'color_material', 'accessories', 'outside_condition', 'inside_condition', 'other', 'smell', 'product_nr'], ['GUCCI GG Pattern Hand Bag Pink Brown', '/collections/gucci/products/ao26972', '49,800', '124542 2888', 'W 7.5 x H 7.5 x D 4.3 "\r\n\r\nHandle Drop. 2.9 "', 'Pink, Brown\r\n/\r\nCanvas, Leather', '-', 'Good condition\r\n\r\nLeather part is Dirt.', 'Good condition', '-', '-', 'AO26972'], ['GUCCI Shelly Line Mini Hand Bag Black Denim', '/collections/gucci/products/ao26973', '32,800', '92821 204991', 'W 6.7 x H 4.3 x D 1.8 "\r\n\r\nHandle Drop. Longest 6.3 "', 'Black, Red, Green\r\n/\r\nDenim, Leather', '-', 'There is sign of use overall.', 'Good condition', '-', '-', 'AO26973'], ['GUCCI GG Pattern Hand Bag Black', '/collections/gucci/products/ao26205', '32,800', '01798 002122', 'W 8.5 x H 4.1 x D 3.5 "\r\n\r\nHandle Drop. 4.1 "', 'Black\r\n/\r\nCanvas, Leather', '-', 'Good condition\r\n\r\nStained', 'Good condition', '-', '-', 'AO26205'], ['GUCCI Kids GG Shelly Line Waist Bum Bag', '/collections/gucci/products/ao25771', '59,800', '311159 002058', 'W 7.4 x H 4.7 x D 1.1 "\r\n\r\nBelt Size. 16.9 - 20.8 "', 'Brown\r\n/\r\nCanvas, Leather', '-', 'Good condition\r\nScratches', 'Excellent condition', '-', '-', 'AO25771'], ['GUCCI Bamboo Backpack Brown', '/collections/gucci/products/ao25546', '69,800', '003.1705.0080', 'W 8.7 " x H 9.4 " x D 2.8 "\r\n\r\nHandle Drop. 2.4 "\r\n\r\nStrap. 23.6 - 29.5 "', 'Brown\r\n/\r\nLeather', 'Dust bag', 'Good condition', 'Good condition', '-', '-', 'AO25546'], ['GUCCI Mini 2way Hand Bag Black', '/collections/gucci/products/ao25460', '79,800', '007.090.0234', 'W 5.1 x H 4.3 x D 2.0 "\r\n\r\nHandle Drop. 2.0 "\r\n\r\nStrap Drop. 23.6 "', 'Black\r\n/\r\nLeather', 'Shoulder strap', 'Good condition', 'Good condition', '-', '-', 'AO25460'], ['GUCCI Mini Party Hand Bag Black Satin', '/collections/gucci/products/ao25459', '69,800', '005.0416.0323.0', 'W 8.3 x H 5.9 x D 2.0 "\r\n\r\nHandle Drop. 1.6 "', 'Black, Gold\r\n/\r\nSatin', 'Dust bag', 'Good condition', 'Good condition\r\n\r\nTag is fraying,and detached.', '-', '-', 'AO25459'], ['GUCCI Jackie Hand Bag Gray Black Velvet', '/collections/gucci/products/ao25212', '39,800', '001.3735.002058', 'W 12.6 x H 8.3 x D 1.2 "\r\n\r\nHandle Drop. 7.1 - 7.9 "', 'Gray, Black\r\n/\r\nVelvet, Leather', 'Dust Bag', 'Good condition\r\n\r\nVelvet: minor dirt.\r\n\r\nLeather part: minor mold stain', 'Good condition', '-', '-', 'AO25212'], ['GUCCI Bamboo Line Chain 2way Mini Hand Bag Black Lizard', '/collections/gucci/products/ao25291', '248,000', '005 781 0258', 'W 6.7 x H 5.1 x D 2.0 "\r\n\r\nHandle Drop. 2.8 "\r\n\r\nShoulder Drop. 24.0 "', 'Black, Brown\r\n/\r\nLizard Leather', 'Shoulder Strap, Manual', 'Excellent condition', 'Good condition\r\n\r\nscratches', '-', '-', 'AO25291'], ['GUCCI GG Shelly Line Boston Hand Bag Brown', '/collections/gucci/products/ao25179', '69,800', '39', 'W 13.0 x H 8.3 x D 6.3 "\r\n\r\nHandle Drop. 4.7 "', 'Brown, Red, Green\r\n/\r\nPVC, Leather', '-', 'There is sign of use overall.\r\n\r\nLeather part: stain.\r\n\r\nZipper rail: rust', 'Good condition', '-', '-', 'AO25179'], ['GUCCI GG Shelly Line Hand Tote Bag Black', '/collections/gucci/products/ao25181', '69,800', '189669 467891', 'W 13.0 x H 14.6 x D 5.1 "\r\n\r\nHandle Drop. 7.5 "', 'Black, Red, Green\r\n/\r\nCanvas, Leather', '-', 'Good condition', 'Good condition', '-', '-', 'AO25181'], ['GUCCI GG Shelly Line Hand Tote Bag Black', '/collections/gucci/products/ao25180', '79,800', '131231 204991', 'W 11.0 x H 12.2 x D 8.7 "\r\n\r\nHandle Drop. 7.9 "', 'Black, Red, Green\r\n/\r\nCanvas, Leather', 'Dust Bag', 'Good condition', 'Good condition', '-', '-', 'AO25180'], ['FENDI Pequin Pattern 2way Hand Bag Brown', '/collections/gucci/products/ao25114', '89,800', '579-262780-069', 'W 11.8 x H 7.5 x D 4.3 "\r\n\r\nHandle Drop. 4.3 "\r\n\r\nStrap Drop. 21.3 "', 'Brown, Black\r\n/\r\nPVC, Leather', 'Shoulder Strap', 'Good condition\r\ ...

# %%
## Create csv and write rows to output file
with open('amoreGucci2.csv','w', newline='') as f_output:
    csv_output = csv.writer(f_output)
    csv_output.writerows(rows)
